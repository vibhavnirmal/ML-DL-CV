# %%
#https://archive.ics.uci.edu/ml/datasets/Iris

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv("F:\MLudemy\MLAZ\MachineLearningPrograms\Classification\iris\\bezdekIris.csv")

# %%
# dataset.head() #to check the first 10 rows of the data set
# dataset.tail() #to check out last 10 row of the data set
# dataset.describe() #to give a statistical summary about the dataset
dataset.sample(5) #pops up 5 random rows from the data set 
# dataset.isnull().sum() #checks out how many null info are on the dataset
# dataset
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 11                  4.8                3.4                 1.6
# 123                 6.3                2.7                 4.9
# 26                  5.0                3.4                 1.6
# 100                 6.3                3.3                 6.0
# 103                 6.3                2.9                 5.6
#
#      petal width in cm           class
# 11                 0.2     Iris-setosa
# 123                1.8  Iris-virginica
# 26                 0.4     Iris-setosa
# 100                2.5  Iris-virginica
# 103                1.8  Iris-virginica

# %%
dataset.hist()
plt.show()

# %%
X = dataset.iloc[:,0:-1].values
y = dataset.iloc[:,-1].values

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 32)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=100)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(accuracy_score(y_test, y_pred)*100)

from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy:{:.2f} %".format(accuracy.mean()*100))
print("Standard Deviation:{:.2f} %".format(accuracy.std()*100))
# Out:
# [[12  0  0]
#  [ 0  9  0]
#  [ 0  0  9]]
# 100.0
# Accuracy:94.17 %
# Standard Deviation:5.34 %

# %% [markdown]
# # K-nearest neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=10, metric='minkowski', p=2)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(accuracy_score(y_test, y_pred)*100)

from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy:{:.2f} %".format(accuracy.mean()*100))
print("Standard Deviation:{:.2f} %".format(accuracy.std()*100))
# Out:
# [[12  0  0]
#  [ 0  9  0]
#  [ 0  2  7]]
# 93.33333333333333
# Accuracy:94.17 %
# Standard Deviation:5.34 %

# %% [markdown]
# # Support vector machine

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='linear', random_state=32)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(accuracy_score(y_test, y_pred)*100)

from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy:{:.2f} %".format(accuracy.mean()*100))
print("Standard Deviation:{:.2f} %".format(accuracy.std()*100))
# Out:
# [[12  0  0]
#  [ 0  9  0]
#  [ 0  0  9]]
# 100.0
# Accuracy:98.33 %
# Standard Deviation:3.33 %

# %% [markdown]
# # Kernel method(SVM)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 32)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(accuracy_score(y_test, y_pred)*100)

from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy:{:.2f} %".format(accuracy.mean()*100))
print("Standard Deviation:{:.2f} %".format(accuracy.std()*100))
# Out:
# [[12  0  0]
#  [ 0  9  0]
#  [ 0  1  8]]
# 96.66666666666667
# Accuracy:94.17 %
# Standard Deviation:5.34 %

# %% [markdown]
# # Naive Bayes classifier

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(accuracy_score(y_test, y_pred)*100)

from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy:{:.2f} %".format(accuracy.mean()*100))
print("Standard Deviation:{:.2f} %".format(accuracy.std()*100))
# Out:
# [[12  0  0]
#  [ 0  9  0]
#  [ 0  1  8]]
# 96.66666666666667
# Accuracy:95.83 %
# Standard Deviation:4.17 %

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 32)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(accuracy_score(y_test, y_pred)*100)

from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy:{:.2f} %".format(accuracy.mean()*100))
print("Standard Deviation:{:.2f} %".format(accuracy.std()*100))
# Out:
# [[12  0  0]
#  [ 0  9  0]
#  [ 0  0  9]]
# 100.0
# Accuracy:94.17 %
# Standard Deviation:5.34 %

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
classifier = XGBClassifier()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(accuracy_score(y_test, y_pred)*100)

from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy:{:.2f} %".format(accuracy.mean()*100))
print("Standard Deviation:{:.2f} %".format(accuracy.std()*100))
# Out:
# [[12  0  0]
#  [ 0  9  0]
#  [ 0  1  8]]
# 96.66666666666667
# Accuracy:94.17 %
# Standard Deviation:3.82 %

# %% [markdown]
# # catboost

# %%
from catboost import CatBoostClassifier
classifier = CatBoostClassifier(iterations=10, learning_rate=0.3, depth=6)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
print(accuracy_score(y_test, y_pred)*100)

from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy:{:.2f} %".format(accuracy.mean()*100))
print("Standard Deviation:{:.2f} %".format(accuracy.std()*100))
# Out:
# 0:	learn: 0.7591740	total: 82.4ms	remaining: 742ms
# 1:	learn: 0.5932259	total: 83.8ms	remaining: 335ms
# 2:	learn: 0.4752483	total: 85.3ms	remaining: 199ms
# 3:	learn: 0.3859468	total: 86.8ms	remaining: 130ms
# 4:	learn: 0.3244325	total: 89.6ms	remaining: 89.6ms
# 5:	learn: 0.2713167	total: 91ms	remaining: 60.6ms
# 6:	learn: 0.2434172	total: 92.4ms	remaining: 39.6ms
# 7:	learn: 0.2173685	total: 93.8ms	remaining: 23.4ms
# 8:	learn: 0.1935281	total: 95.2ms	remaining: 10.6ms
# 0:	learn: 0.7848222	total: 2.2ms	remaining: 19.8ms
# 1:	learn: 0.6188876	total: 3.58ms	remaining: 14.3ms
# 2:	learn: 0.5021814	total: 4.93ms	remaining: 11.5ms
# 3:	learn: 0.4243928	total: 6.29ms	remaining: 9.44ms
# 4:	learn: 0.3653820	total: 8.16ms	remaining: 8.16ms
# 5:	learn: 0.3089095	total: 9.88ms	remaining: 6.58ms
# 6:	learn: 0.2741060	total: 12.1ms	remaining: 5.17ms
# 7:	learn: 0.2438238	total: 13.5ms	remaining: 3.37ms
# 8:	learn: 0.2236722	total: 14.8ms	remaining: 1.65ms
# 9:	learn: 0.2014878	total: 16.1ms	remaining: 0us
# Accuracy:95.00 %
# Standard Deviation:4.08 %

# %% [markdown]
# # Artificial Neural Net

# %%
from keras.utils import np_utils
dummy_y = np_utils.to_categorical(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, dummy_y, test_size = 0.24, random_state = 32)

# %%
import tensorflow as tf

ann = tf.keras.models.Sequential()

ann.add(tf.keras.layers.Dense(units=8, input_dim=4,  activation='relu'))
ann.add(tf.keras.layers.Dense(units=10, activation='relu'))
ann.add(tf.keras.layers.Dense(units=15, activation='relu'))
ann.add(tf.keras.layers.Dense(units=15, activation='relu'))
ann.add(tf.keras.layers.Dense(units=3, activation='sigmoid'))

ann.compile(optimizer = 'RMSprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
ann.fit(X_train, y_train, epochs=100, validation_data = (X_test, y_test))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 244ms/step - loss: 1.1145 - accuracy: 0.3070 - val_loss: 1.0835 - val_accuracy: 0.4167
# Epoch 2/100
# 4/4 [==============================] - 0s 58ms/step - loss: 1.0944 - accuracy: 0.3070 - val_loss: 1.0606 - val_accuracy: 0.4167
# Epoch 3/100
# 4/4 [==============================] - 0s 82ms/step - loss: 1.0702 - accuracy: 0.3070 - val_loss: 1.0260 - val_accuracy: 0.4167
# Epoch 4/100
# 4/4 [==============================] - 0s 97ms/step - loss: 1.0426 - accuracy: 0.3070 - val_loss: 0.9990 - val_accuracy: 0.4167
# Epoch 5/100
# 4/4 [==============================] - 0s 92ms/step - loss: 1.0211 - accuracy: 0.3070 - val_loss: 0.9725 - val_accuracy: 0.4167
# Epoch 6/100
# 4/4 [==============================] - 0s 67ms/step - loss: 1.0007 - accuracy: 0.3070 - val_loss: 0.9501 - val_accuracy: 0.4167
# Epoch 7/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.9834 - accuracy: 0.3070 - val_loss: 0.9308 - val_accuracy: 0.4167
# Epoch 8/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.9680 - accuracy: 0.3070 - val_loss: 0.9125 - val_accuracy: 0.5556
# Epoch 9/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.9517 - accuracy: 0.5088 - val_loss: 0.8931 - val_accuracy: 0.6111
# Epoch 10/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.9360 - accuracy: 0.5351 - val_loss: 0.8735 - val_accuracy: 0.6389
# Epoch 11/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.9210 - accuracy: 0.6404 - val_loss: 0.8535 - val_accuracy: 0.6667
# Epoch 12/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0
100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0935 - accuracy: 0.9649 - val_loss: 0.0539 - val_accuracy: 1.0000
# Epoch 80/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1040 - accuracy: 0.9649 - val_loss: 0.0557 - val_accuracy: 1.0000
# Epoch 81/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0976 - accuracy: 0.9649 - val_loss: 0.0501 - val_accuracy: 1.0000
# Epoch 82/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0903 - accuracy: 0.9737 - val_loss: 0.0590 - val_accuracy: 1.0000
# Epoch 83/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0923 - accuracy: 0.9649 - val_loss: 0.0681 - val_accuracy: 0.9722
# Epoch 84/100
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0855 - accuracy: 0.9649 - val_loss: 0.0478 - val_accuracy: 1.0000
# Epoch 85/100
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0948 - accuracy: 0.9737 - val_loss: 0.0603 - val_accuracy: 0.9722
# Epoch 86/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0981 - accuracy: 0.9561 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 0s 90ms/step - loss: 0.0926 - accuracy: 0.9737 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 88/100
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0944 - accuracy: 0.9561 - val_loss: 0.0505 - val_accuracy: 1.0000
# Epoch 89/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0855 - accuracy: 0.9561 - val_loss: 0.0574 - val_accuracy: 1.0000
# Epoch 90/100
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0857 - accuracy: 0.9649 - val_loss: 0.0763 - val_accuracy: 0.9722
# Epoch 91/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0810 - accuracy: 0.9737 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 92/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0827 - accuracy: 0.9737 - val_loss: 0.0414 - val_accuracy: 1.0000
# Epoch 93/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0782 - accuracy: 0.9737 - val_loss: 0.1051 - val_accuracy: 0.9444
# Epoch 94/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0884 - accuracy: 0.9649 - val_loss: 0.0541 - val_accuracy: 0.9722
# Epoch 95/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0842 - accuracy: 0.9649 - val_loss: 0.0492 - val_accuracy: 1.0000
# Epoch 96/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0836 - accuracy: 0.9737 - val_loss: 0.0591 - val_accuracy: 0.9722
# Epoch 97/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0883 - accuracy: 0.9561 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 98/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0841 - accuracy: 0.9737 - val_loss: 0.0344 - val_accuracy: 1.0000
# Epoch 99/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0897 - accuracy: 0.9649 - val_loss: 0.0701 - val_accuracy: 0.9722
# Epoch 100/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0833 - accuracy: 0.9649 - val_loss: 0.0511 - val_accuracy: 1.0000
