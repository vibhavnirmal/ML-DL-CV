# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dataset = pd.read_csv("trafficstop.csv")

# %%
dataset
# Out:
#        Month  RsnStop  OffRace  OffMale  OffYrsSrv  DrvRace  DrvHisp  DrvMale  \
# 0          8        8      3.0        0         22        2        2        1
# 1          1        8      5.0        1         18        2        2        1
# 2          1        8      5.0        1         18        2        2        0
# 3         11        7      3.0        0         23        5        1        1
# 4         12        7      3.0        0         23        5        2        1
# 5          4       10      5.0        1         22        2        2        1
# 6          1        5      5.0        1         14        2        2        1
# 7          3        8      5.0        1          7        2        2        1
# 8          8        8      5.0        1          9        2        2        1
# 9          8        5      5.0        1         17        5        2        1
# 10         3        4      5.0        0          3        5        2        0
# 11        11       10      3.0        1          7        2        2        1
# 12        11       10      5.0        1          4        2        2        0
# 13         2        7      5.0        1          9        2        2        0
# 14         1        7      2.0        1         10        2        2        0
# 15         3       10      5.0        1         17        5        2        0
# 16         4        7      5.0        1         22        4        2        0
# 17         4        7      5.0        1         22        2        2        0
# 18         4        7      5.0        1         22        4        1        1
# 19         4        9      5.0        1          7        2        2        1
# 20         4        9      5.0        1          7        2        2        1
# 21         4       10      5.0        1          7        2        2        1
# 22         4        4      5.0        1          7        2        2        1
# 23         4       10      5.0        1          3        2        2        0
# 24         1       10      2.0        1         19        5        2        0
# 25         1        7      5.0        1          6        5        2        0
# 26         1        5      5.0        1          3        2        2        0
# 27         1       10      5.0        1          1        2        2        1
# 28         1       10      5.0        1         23        2        2        0
# 29         1        4      3.0        1          2        5        1        1
# ...      ...      ...      ...      ...        ...      ...      ...      ...
# 79854     12        7      3.0        1         15        2        2        1
# 79855     12       10      5.0        1         23        5        2        0
# 79856     12        7      3.0        1         15        5        1        0
# 79857     12        7      2.0        1         20        5        1        1
# 79858     12        7      3.0        1         15        2        2        0
# 79859     12       10      3.0        1          7        2        2        1
# 79860     12        8      5.0        1         16        5        2        1
# 79861      2        7      5.0        1          7        2        2        1
# 79862      6        9      5.0        1         11        5        2        0
# 79863      5        3      5.0        1          9        5        2        1
# 79864      9        9      5.0        1         11        2        2        1
# 79865      2       10      3.0        1         23        5        2        1
# 79866      6        7      5.0        1         22        2        2        1
# 79867      2        7      5.0        1         17        2        2        1
# 79868      7        7      3.0        1         21        2        2        0
# 79869      8        5      3.0        1         25        5        2        1
# 79870      3       10      5.0        1          3        5        1        1
# 79871      9        7      5.0        1         17        2        2        1
# 79872     10        3      5.0        1         16        2        2        1
# 79873      4        8      5.0        1          8        5        2        0
# 79874      6        9      5.0        1         28        2        2        0
# 79875      7       10      5.0        1         11        2        2        0
# 79876      7        3      3.0        1          8        5        1        0
# 79877      8        7      5.0        1         21        2        2        0
# 79878      8        7      5.0        1         21        2        2        0
# 79879     10        9      5.0        1          9        5        2        1
# 79880     11       10      5.0        1         20        5        2        0
# 79881     11        7      5.0        1         10        4        2        1
# 79882     12       10      5.0        1         11        1        2        1
# 79883     11        9      3.0        1         19        5        2        1
#
#        DrvAge  SrchVhcl  RsltStop
# 0          40         0         2
# 1          26         1         4
# 2          25         0         2
# 3          41         0         2
# 4          53         0         2
# 5          24         0         2
# 6          50         0         2
# 7          38         1         4
# 8          25         0         2
# 9          43         0         2
# 10         50         0         5
# 11         35         0         2
# 12         18         0         2
# 13         24         0         4
# 14         23         0         4
# 15         33         0         2
# 16         28         0         4
# 17         36         0         4
# 18         41         0         4
# 19         31         0         2
# 20         21         0         2
# 21         28         1         4
# 22         35         0         1
# 23         24         0         4
# 24         26         0         2
# 25         19         0         2
# 26         20         0         2
# 27         55         0         2
# 28         39         0         2
# 29         33         0         2
# ...       ...       ...       ...
# 79854      50         0         4
# 79855      60         0         4
# 79856      40         0         4
# 79857      34         0         4
# 79858      20         0         4
# 79859      36         0         4
# 79860      52         0         2
# 79861      21         0         2
# 79862      20         0         2
# 79863      38         0         2
# 79864      60         0         2
# 79865      30         0         4
# 79866      34         0         4
# 79867      19         0         4
# 79868      27         0         4
# 79869      45         0         3
# 79870      55         0         4
# 79871      21         0         4
# 79872      25         0         4
# 79873      30         0         2
# 79874      64         0         4
# 79875      48         0         2
# 79876      42         0         2
# 79877      35         0         2
# 79878      35         0         2
# 79879      31         0         4
# 79880      50         0         1
# 79881      72         0         4
# 79882      26         0         2
# 79883      46         0         2
#
# [79884 rows x 11 columns]

# %%
X = dataset.iloc[:,:-1].values

# %%
Y = dataset.iloc[:,10].values

# %%
dataset.isnull().sum()
# Out:
# Month          0
# RsnStop        0
# OffRace      721
# OffMale        0
# OffYrsSrv      0
# DrvRace        0
# DrvHisp        0
# DrvMale        0
# DrvAge         0
# SrchVhcl       0
# RsltStop       0
# dtype: int64

# %%
dataset = dataset.replace(np.nan, 4.0)

# %%
dataset.isnull().sum()
# Out:
# Month        0
# RsnStop      0
# OffRace      0
# OffMale      0
# OffYrsSrv    0
# DrvRace      0
# DrvHisp      0
# DrvMale      0
# DrvAge       0
# SrchVhcl     0
# RsltStop     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-cc2acbfe448e> in <module>()
# ----> 1 regressor.fit(X_train, Y_train)
#
# C:\anaconda\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
from sklearn.preprocessing import StandardScaler

# %%
Sc_X = StandardScaler()

# %%
X_train = Sc_X.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-138b66a3b9cd> in <module>()
# ----> 1 X_train = Sc_X.fit_transform(X_train)
#
# C:\anaconda\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# C:\anaconda\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     588         # Reset internal state before fitting
#     589         self._reset()
# --> 590         return self.partial_fit(X, y)
#     591
#     592     def partial_fit(self, X, y=None):
#
# C:\anaconda\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     610         """
#     611         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
# --> 612                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES)
#     613
#     614         # Even in the case of `with_mean=False`, we update the mean anyway
#
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
print (X_train.min().min())
# Out:
# nan

# %%
print (dataset.index[np.isnan(dataset).any(axis=1)])
# Out:
# Int64Index([], dtype='int64')

# %%
print (dataset.columns[np.isnan(dataset).any()])
# Out:
# Index([], dtype='object')
